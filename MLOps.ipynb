# %% [markdown]
# # CREATION DES CLASSES

# %% [markdown]
# ## comment les classes sont construites à partir des données EEG

# %% [markdown]
# ## comment les données sont organisées

# %% [markdown]
# ## identifier où les étiquettes sont créées dans le code

# %% [markdown]
# # PIPELINE D'ENTRAINEMENT

# %% [markdown]
# ## comment le modèle est instancié

# %% [markdown]
#  ## comment lancer l'entraînement

# %% [markdown]
# ## identifier les hyperparamètres

# %% [markdown]
# ## comment les checkpoints du modèle sont sauvegardés

# %% [markdown]
# # PIPELINE D'EVALUATION

# %% [markdown]
# ## comment charger un modèle entraîné

# %% [markdown]
# ## comment lancer l'évaluation sur le jeu de test

# %% [markdown]
# ## le calcul des métriques
